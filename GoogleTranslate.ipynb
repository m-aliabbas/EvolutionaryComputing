# %%
#These Libraries must be install
#use command pip install googletrans , python_docx, docx


from docx import Document
from googletrans import Translator 



translator = Translator()
file_name="1.docx" #Name of InputFile
inputDocx = Document(file_name)
outputDocx=Document()


#Language List

LANGUAGES = {
    'af': 'afrikaans',
    'sq': 'albanian',
    'am': 'amharic',
    'ar': 'arabic',
    'hy': 'armenian',
    'az': 'azerbaijani',
    'eu': 'basque',
    'be': 'belarusian',
    'bn': 'bengali',
    'bs': 'bosnian',
    'bg': 'bulgarian',
    'ca': 'catalan',
    'ceb': 'cebuano',
    'ny': 'chichewa',
    'zh-cn': 'chinese (simplified)',
    'zh-tw': 'chinese (traditional)',
    'co': 'corsican',
    'hr': 'croatian',
    'cs': 'czech',
    'da': 'danish',
    'nl': 'dutch',
    'en': 'english',
    'eo': 'esperanto',
    'et': 'estonian',
    'tl': 'filipino',
    'fi': 'finnish',
    'fr': 'french',
    'fy': 'frisian',
    'gl': 'galician',
    'ka': 'georgian',
    'de': 'german',
    'el': 'greek',
    'gu': 'gujarati',
    'ht': 'haitian creole',
    'ha': 'hausa',
    'haw': 'hawaiian',
    'iw': 'hebrew',
    'hi': 'hindi',
    'hmn': 'hmong',
    'hu': 'hungarian',
    'is': 'icelandic',
    'ig': 'igbo',
    'id': 'indonesian',
    'ga': 'irish',
    'it': 'italian',
    'ja': 'japanese',
    'jw': 'javanese',
    'kn': 'kannada',
    'kk': 'kazakh',
    'km': 'khmer',
    'ko': 'korean',
    'ku': 'kurdish (kurmanji)',
    'ky': 'kyrgyz',
    'lo': 'lao',
    'la': 'latin',
    'lv': 'latvian',
    'lt': 'lithuanian',
    'lb': 'luxembourgish',
    'mk': 'macedonian',
    'mg': 'malagasy',
    'ms': 'malay',
    'ml': 'malayalam',
    'mt': 'maltese',
    'mi': 'maori',
    'mr': 'marathi',
    'mn': 'mongolian',
    'my': 'myanmar (burmese)',
    'ne': 'nepali',
    'no': 'norwegian',
    'ps': 'pashto',
    'fa': 'persian',
    'pl': 'polish',
    'pt': 'portuguese',
    'pa': 'punjabi',
    'ro': 'romanian',
    'ru': 'russian',
    'sm': 'samoan',
    'gd': 'scots gaelic',
    'sr': 'serbian',
    'st': 'sesotho',
    'sn': 'shona',
    'sd': 'sindhi',
    'si': 'sinhala',
    'sk': 'slovak',
    'sl': 'slovenian',
    'so': 'somali',
    'es': 'spanish',
    'su': 'sundanese',
    'sw': 'swahili',
    'sv': 'swedish',
    'tg': 'tajik',
    'ta': 'tamil',
    'te': 'telugu',
    'th': 'thai',
    'tr': 'turkish',
    'uk': 'ukrainian',
    'ur': 'urdu',
    'uz': 'uzbek',
    'vi': 'vietnamese',
    'cy': 'welsh',
    'xh': 'xhosa',
    'yi': 'yiddish',
    'yo': 'yoruba',
    'zu': 'zulu',
    'fil': 'Filipino',
    'he': 'Hebrew'
}

LANGCODES = dict(map(reversed, LANGUAGES.items()))




class MyDict(dict):
    def __getitem__(self, key):
        return dict.get(self, key)
      
def detectL(text="It is english Text"):
  return translator.detect(text).lang


src=MyDict({"1":'en',"2":'ar',"3":'ur',"4":'zn-ch',"5":'zn-tw',"6":'ja',"7":'hi',"8":'fa',"0":detectL})
des=MyDict({"1":'en',"2":'ar',"3":'ur',"4":'zn-ch',"5":'zn-tw',"6":'ja',"7":'hi',"8":'fa'})
source=input("Please Select Source Language from Following\n [1] English \t [2] Arabic \t [3] Urdu\t  [4] chinese (Simplified) \n [5] Chinese (traditional) [6] Japanies [7] Hindi [8] Perisan \n [0] Press Zero for Auto Language Detection (if source language is not in list) ")
dest=input("Please Select Source Language from Following\n [1] English \t [2] Arabic \t [3] Urdu \t  [4] chinese (Simplified) \n [5] Chinese (traditional) [6] Japanies [7] Hindi [8] Perisan")
s=src[source]
if s is None:
  s='en'
if type(s) is not type("9"):
  s=s(doc.paragraphs[0].text)
d=src[dest]
if d is None:
  d='en'

for i in inputDocx.paragraphs:
  t=i.text
  try:
    try:
      t1=translator.translate(t, src=s,dest=d)
      outputDocx.add_paragraph(t1.text)
    except:
      pass
  except:
    pass
outputDocx.save("output.docx") #Save output to output.docx
